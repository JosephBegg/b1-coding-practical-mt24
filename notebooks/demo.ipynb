# %%
# Add relevant Jupyter notebook extensions

# %%
# You can double-check your Python path like this...
import sys, os 
sys.path.append(os.path.abspath("../"))
print(sys.path)
print(os.path.exists("../data/mission.csv"))
# Out:
# ['/Library/Frameworks/Python.framework/Versions/3.12/lib/python312.zip', '/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12', '/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/lib-dynload', '', '/Users/joebegg/Documents/VSCODE/b1-coding-practical-mt24/.venv/lib/python3.12/site-packages', '/Users/joebegg/Documents/VSCODE/b1-coding-practical-mt24', '/Users/joebegg/Documents/VSCODE/b1-coding-practical-mt24', '/Users/joebegg/Documents/VSCODE/b1-coding-practical-mt24', '/Users/joebegg/Documents/VSCODE/b1-coding-practical-mt24', '/Users/joebegg/Documents/VSCODE/b1-coding-practical-mt24', '/Users/joebegg/Documents/VSCODE/b1-coding-practical-mt24', '/Users/joebegg/Documents/VSCODE/b1-coding-practical-mt24', '/Users/joebegg/Documents/VSCODE/b1-coding-practical-mt24', '/Users/joebegg/Documents/VSCODE/b1-coding-practical-mt24', '/Users/joebegg/Documents/VSCODE/b1-coding-practical-mt24', '/Users/joebegg/Documents/VSCODE/b1-coding-practical-mt24', '/Users/joebegg/Documents/VSCODE/b1-coding-practical-mt24', '/Users/joebegg/Documents/VSCODE/b1-coding-practical-mt24', '/Users/joebegg/Documents/VSCODE/b1-coding-practical-mt24', '/Users/joebegg/Documents/VSCODE/b1-coding-practical-mt24', '/Users/joebegg/Documents/VSCODE/b1-coding-practical-mt24', '/Users/joebegg/Documents/VSCODE/b1-coding-practical-mt24', '/Users/joebegg/Documents/VSCODE/b1-coding-practical-mt24', '/Users/joebegg/Documents/VSCODE/b1-coding-practical-mt24', '/Users/joebegg/Documents/VSCODE/b1-coding-practical-mt24', '/Users/joebegg/Documents/VSCODE/b1-coding-practical-mt24', '/Users/joebegg/Documents/VSCODE/b1-coding-practical-mt24', '/Users/joebegg/Documents/VSCODE/b1-coding-practical-mt24', '/Users/joebegg/Documents/VSCODE/b1-coding-practical-mt24', '/Users/joebegg/Documents/VSCODE/b1-coding-practical-mt24', '/Users/joebegg/Documents/VSCODE/b1-coding-practical-mt24', '/Users/joebegg/Documents/VSCODE/b1-coding-practical-mt24', '/Users/joebegg/Documents/VSCODE/b1-coding-practical-mt24']
# True

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules
from uuv_mission.dynamic import Mission
from uuv_mission.dynamic import Submarine
from uuv_mission.dynamic import ClosedLoop
from uuv_mission.control import PDController

sub = Submarine()
# Instantiate your controller (depending on your implementation)
controller = PDController(Kp=0.2, Kd=0.6)
                    
closed_loop = ClosedLoop(sub, controller)
mission = Mission.from_csv("../data/mission.csv") # You must implement this method in the Mission class

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
controller.reset()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[85], line 16
#      14 trajectory = closed_loop.simulate_with_random_disturbances(mission)
#      15 trajectory.plot_completed_mission(mission)
# ---> 16 controller.reset()
#
# AttributeError: 'PDController' object has no attribute 'reset'
